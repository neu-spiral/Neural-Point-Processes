# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
savepath = "../checkpoints"
files = os.listdir(savepath)
files
# Out:
# ['logs', 'save', 'savelabels.npy', 'savepredictions.npy']

# %%
lbls = np.load(os.path.join(savepath, files[2]))
preds = np.load(os.path.join(savepath, files[3]))

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))
ax[0].imshow(preds[0][0], cmap='gray')
ax[1].imshow(lbls[0][0], cmap='gray')
